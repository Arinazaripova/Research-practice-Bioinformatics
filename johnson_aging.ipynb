# %%
import pandas as pd               
import numpy as np                
import matplotlib.pyplot as plt   
import matplotlib

# %%
johnson_aging = pd.read_csv('/Users/macbook/Desktop/data/johnson_20/Aging/data/0.Traits.csv')
johnson_aging
# Out:
#        SampleID  Sex   Age   PMI  Batch  RunOrder
# 0     ag_02_gis  0.7  46.7  23.6      1         1
# 1    ag_03_0247  1.0  55.0  16.0      1         2
# 2    ag_04_0210  0.0  44.0  27.0      1         3
# 3    ag_05_0306  0.0  52.0  36.0      1         4
# 4    ag_06_0120  0.0  42.0  42.0      1         5
# ..          ...  ...   ...   ...    ...       ...
# 88   ag_99_0193  1.0  50.0  11.0      3        89
# 89  ag_100_0081  1.0  62.0  14.0      3        90
# 90  ag_101_0479  1.0  44.0  13.0      3        91
# 91  ag_102_0463  1.0  49.0  16.0      3        92
# 92   ag_104_gis  0.7  46.7  23.6      3        93
#
# [93 rows x 6 columns]

# %%
johnson_aging['SampleID'].nunique()
# Out:
# 93

# %%
johnson_aging.shape
# Out:
# (93, 6)

# %%
aging_c = pd.read_excel('/Users/macbook/Desktop/data/johnson_20/Aging/data/3.cleanDat.xlsx')

# %%
print(aging_c.shape)
aging_c.head(5)
# Out:
# (2756, 85)
#   UniqueID (Symbol|UniprotID)  ag_03_0247  ag_04_0210  ag_05_0306  ag_06_0120  \
# 0           TMPRSS13|Q9BYE2-3   -0.290044   -0.527683   -0.217489    0.683755
# 1                |CON__P01966   -2.406303   -1.372356   -2.277019   -2.094702
# 2                  ALB|P02768   -0.779293   -0.764114   -0.321117   -1.405034
# 3                KRT10|P13645    0.164756   -0.247998   -0.992059    0.111673
# 4                |CON__P15636   -0.737010   -0.542527   -0.376441   -0.646228
#
#    ag_07_0228  ag_08_0448  ag_09_0562  ag_10_0600  ag_11_0227  ...  \
# 0   -0.820121   -0.896638   -0.062737   -0.007869   -0.199193  ...
# 1   -1.851561    6.951933    7.381273   -1.875243   -1.943640  ...
# 2   -0.475328   -0.537492   -0.169257   -0.003034   -0.085535  ...
# 3   -0.121443    0.177551   -0.835565   -0.910166   -0.222788  ...
# 4   -0.533868   -0.817672   -0.379829   -0.777756   -0.396635  ...
#
#    ag_93_0253  ag_94_0546  ag_95_0135  ag_96_0122  ag_97_0635  ag_98_0111  \
# ...

# %%
aging_c = aging_c.T

# %%
aging_c
# Out:
#                                           0             1           2     \
# UniqueID (Symbol|UniprotID)  TMPRSS13|Q9BYE2-3  |CON__P01966  ALB|P02768
# ag_03_0247                           -0.290044     -2.406303   -0.779293
# ag_04_0210                           -0.527683     -1.372356   -0.764114
# ag_05_0306                           -0.217489     -2.277019   -0.321117
# ag_06_0120                            0.683755     -2.094702   -1.405034
# ...                                        ...           ...         ...
# ag_98_0111                           -0.855352     -0.308347    0.603076
# ag_99_0193                           -0.262403     -1.101195    0.562487
# ag_100_0081                          -0.355238      7.348375   -1.045863
# ag_101_0479                            -0.2785     -2.305817   -0.936118
# ag_102_0463                           -0.68118      -2.23467   -0.679329
#
#                                      3             4            5     \
# ...

# %%
first = aging_c.iloc[0]
first
# Out:
# 0        TMPRSS13|Q9BYE2-3
# 1             |CON__P01966
# 2               ALB|P02768
# 3             KRT10|P13645
# 4             |CON__P15636
#                ...
# 2751              0|M0QYT0
# 2752           SARS|P49591
# 2753           TPM1|Q6ZN40
# 2754    RPS10-NUDT3|S4R435
# 2755       NFASC|O94856-11
# Name: UniqueID (Symbol|UniprotID), Length: 2756, dtype: object

# %%
aging_c.columns = first
aging_c.reset_index(inplace = True)
aging_c
# Out:
# UniqueID (Symbol|UniprotID)                        index  TMPRSS13|Q9BYE2-3  \
# 0                            UniqueID (Symbol|UniprotID)  TMPRSS13|Q9BYE2-3
# 1                                             ag_03_0247          -0.290044
# 2                                             ag_04_0210          -0.527683
# 3                                             ag_05_0306          -0.217489
# 4                                             ag_06_0120           0.683755
# ..                                                   ...                ...
# 80                                            ag_98_0111          -0.855352
# 81                                            ag_99_0193          -0.262403
# 82                                           ag_100_0081          -0.355238
# 83                                           ag_101_0479            -0.2785
# 84                                           ag_102_0463           -0.68118
#
# ...

# %%
aging_c.iloc[0]
# Out:
# UniqueID (Symbol|UniprotID)
# index                 UniqueID (Symbol|UniprotID)
# TMPRSS13|Q9BYE2-3               TMPRSS13|Q9BYE2-3
# |CON__P01966                         |CON__P01966
# ALB|P02768                             ALB|P02768
# KRT10|P13645                         KRT10|P13645
#                                  ...
# 0|M0QYT0                                 0|M0QYT0
# SARS|P49591                           SARS|P49591
# TPM1|Q6ZN40                           TPM1|Q6ZN40
# RPS10-NUDT3|S4R435             RPS10-NUDT3|S4R435
# NFASC|O94856-11                   NFASC|O94856-11
# Name: 0, Length: 2757, dtype: object

# %%
aging_c.drop(index =aging_c.index[0], inplace = True)
aging_c
# Out:
# UniqueID (Symbol|UniprotID)        index TMPRSS13|Q9BYE2-3 |CON__P01966  \
# 1                             ag_03_0247         -0.290044    -2.406303
# 2                             ag_04_0210         -0.527683    -1.372356
# 3                             ag_05_0306         -0.217489    -2.277019
# 4                             ag_06_0120          0.683755    -2.094702
# 5                             ag_07_0228         -0.820121    -1.851561
# ..                                   ...               ...          ...
# 80                            ag_98_0111         -0.855352    -0.308347
# 81                            ag_99_0193         -0.262403    -1.101195
# 82                           ag_100_0081         -0.355238     7.348375
# 83                           ag_101_0479           -0.2785    -2.305817
# 84                           ag_102_0463          -0.68118     -2.23467
#
# UniqueID (Symbol|UniprotID) ALB|P02768 KRT10|P13645 |CON__P15636 KRT2|P35908  \
# ...

# %%
aging_c.rename(columns={'index': 'SampleID'}, inplace=True)
aging_c
# Out:
# UniqueID (Symbol|UniprotID)     SampleID TMPRSS13|Q9BYE2-3 |CON__P01966  \
# 1                             ag_03_0247         -0.290044    -2.406303
# 2                             ag_04_0210         -0.527683    -1.372356
# 3                             ag_05_0306         -0.217489    -2.277019
# 4                             ag_06_0120          0.683755    -2.094702
# 5                             ag_07_0228         -0.820121    -1.851561
# ..                                   ...               ...          ...
# 80                            ag_98_0111         -0.855352    -0.308347
# 81                            ag_99_0193         -0.262403    -1.101195
# 82                           ag_100_0081         -0.355238     7.348375
# 83                           ag_101_0479           -0.2785    -2.305817
# 84                           ag_102_0463          -0.68118     -2.23467
#
# UniqueID (Symbol|UniprotID) ALB|P02768 KRT10|P13645 |CON__P15636 KRT2|P35908  \
# ...

# %%
aging_c['SampleID'].nunique()
# Out:
# 84

# %%
df = pd.merge(johnson_aging, aging_c ,on='SampleID', how='right')
# df['y'] = df['Group'] == 'AD'
df.drop(columns=['SampleID'], inplace=True)
print(df.shape)
df.head(5)
# Out:
# (84, 2761)
#    Sex   Age   PMI  Batch  RunOrder TMPRSS13|Q9BYE2-3 |CON__P01966 ALB|P02768  \
# 0  1.0  55.0  16.0      1         2         -0.290044    -2.406303  -0.779293
# 1  0.0  44.0  27.0      1         3         -0.527683    -1.372356  -0.764114
# 2  0.0  52.0  36.0      1         4         -0.217489    -2.277019  -0.321117
# 3  0.0  42.0  42.0      1         5          0.683755    -2.094702  -1.405034
# 4  1.0  47.0  37.0      1         6         -0.820121    -1.851561  -0.475328
#
#   KRT10|P13645 |CON__P15636  ... ACTN4|K7EJH8 GFAP|K7EKD1 LONP1|P36776-2  \
# 0     0.164756     -0.73701  ...    -0.088991   -2.402048      -0.320857
# 1    -0.247998    -0.542527  ...    -0.393968   -0.255081      -0.176921
# 2    -0.992059    -0.376441  ...    -0.760773         NaN       0.108751
# 3     0.111673    -0.646228  ...    -0.891131   -2.406138       0.412171
# 4    -0.121443    -0.533868  ...    -0.498356   -0.061359       0.093561
#
# ...

# %%
df.dtypes
# Out:
# Sex                   float64
# Age                   float64
# PMI                   float64
# Batch                   int64
# RunOrder                int64
#                        ...
# 0|M0QYT0               object
# SARS|P49591            object
# TPM1|Q6ZN40            object
# RPS10-NUDT3|S4R435     object
# NFASC|O94856-11        object
# Length: 2761, dtype: object

# %%
for col in df.columns:
    try:
        df[col] = df[col].astype(float)
    except ValueError:
        print(col)
        pass

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Columns: 2761 entries, Sex to NFASC|O94856-11
# dtypes: float64(2761)
# memory usage: 1.8 MB

# %%
df.isnull().sum()
# Out:
# Sex                   0
# Age                   0
# PMI                   0
# Batch                 0
# RunOrder              0
#                      ..
# 0|M0QYT0              0
# SARS|P49591           0
# TPM1|Q6ZN40           0
# RPS10-NUDT3|S4R435    0
# NFASC|O94856-11       0
# Length: 2761, dtype: int64

# %%
df.isnull().sum(axis=1).sort_values()
# Out:
# 33    116
# 46    123
# 48    125
# 38    128
# 32    129
#      ...
# 34    253
# 29    253
# 10    265
# 15    269
# 18    294
# Length: 84, dtype: int64

# %%
# Missung values imputatio with median
df[df.columns] = df[df.columns].apply(pd.to_numeric, errors = 'coerce')
df = df.fillna(df.median())
df

# %%
from sklearn.impute import KNNImputer

knn_imp = KNNImputer(n_neighbors = 5, weights = 'distance')
imputed_df = knn_imp.fit_transform(df)

df_knn_filled = pd.DataFrame(imputed_df, columns = df.columns)
df_knn_filled
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(strategy='median')
imp_mean.fit_transform(df)

df_imputed = pd.DataFrame(imp_mean.fit_transform(df), columns = df.columns)
df_imputed
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...
