# %%
import pandas as pd               
import numpy as np                
import matplotlib.pyplot as plt   
import matplotlib

# %%
# MMSE - Mini Mental State Examination
johnson_consensus = pd.read_csv('/Users/macbook/Desktop/data/johnson_20/Consensus/data/0.Traits.csv')
johnson_consensus
# Out:
#            Unnamed: 0   Age  Sex   PMI  CERAD  Braak  Group    Batch  \
# 0        ACT.ad_act10  86.0  1.0  3.50    3.0    6.0     AD      NaN
# 1        ACT.ad_act62  90.0  0.0  3.50    3.0    6.0     AD      NaN
# 2        ACT.ad_act23  80.0  0.0  5.00    3.0    6.0     AD      NaN
# 3        ACT.ad_act52  90.0  0.0  3.85    3.0    5.0     AD      NaN
# 4        ACT.ad_act50  90.0  0.0  2.25    3.0    5.0     AD      NaN
# ..                ...   ...  ...   ...    ...    ...    ...      ...
# 640  MSSB.b7_aegis_23   NaN  NaN   NaN    NaN    NaN  aegis  MSSB.b7
# 641  MSSB.b7_aegis_44   NaN  NaN   NaN    NaN    NaN  aegis  MSSB.b7
# 642  MSSB.b7_bmgis_01   NaN  NaN   NaN    NaN    NaN  bmgis  MSSB.b7
# 643  MSSB.b7_bmgis_22   NaN  NaN   NaN    NaN    NaN  bmgis  MSSB.b7
# 644  MSSB.b7_bmgis_43   NaN  NaN   NaN    NaN    NaN  bmgis  MSSB.b7
#
#     ApoE.Genotype  ApoE.Risk  MMSE  CDR  CASI  ABETA.2pep.corrected
# 0             NaN        NaN   NaN  NaN  46.0              1.453064
# ...

# %%
johnson_consensus.rename(columns={'Unnamed: 0': 'SampleID'}, inplace=True)
johnson_consensus
# Out:
#              SampleID   Age  Sex   PMI  CERAD  Braak  Group    Batch  \
# 0        ACT.ad_act10  86.0  1.0  3.50    3.0    6.0     AD      NaN
# 1        ACT.ad_act62  90.0  0.0  3.50    3.0    6.0     AD      NaN
# 2        ACT.ad_act23  80.0  0.0  5.00    3.0    6.0     AD      NaN
# 3        ACT.ad_act52  90.0  0.0  3.85    3.0    5.0     AD      NaN
# 4        ACT.ad_act50  90.0  0.0  2.25    3.0    5.0     AD      NaN
# ..                ...   ...  ...   ...    ...    ...    ...      ...
# 640  MSSB.b7_aegis_23   NaN  NaN   NaN    NaN    NaN  aegis  MSSB.b7
# 641  MSSB.b7_aegis_44   NaN  NaN   NaN    NaN    NaN  aegis  MSSB.b7
# 642  MSSB.b7_bmgis_01   NaN  NaN   NaN    NaN    NaN  bmgis  MSSB.b7
# 643  MSSB.b7_bmgis_22   NaN  NaN   NaN    NaN    NaN  bmgis  MSSB.b7
# 644  MSSB.b7_bmgis_43   NaN  NaN   NaN    NaN    NaN  bmgis  MSSB.b7
#
#     ApoE.Genotype  ApoE.Risk  MMSE  CDR  CASI  ABETA.2pep.corrected
# 0             NaN        NaN   NaN  NaN  46.0              1.453064
# ...

# %%
johnson_consensus.shape
# Out:
# (645, 14)

# %%
johnson_consensus.isna().sum()
# Out:
# SampleID                  0
# Age                      66
# Sex                      66
# PMI                      66
# CERAD                    66
# Braak                    85
# Group                     0
# Batch                   112
# ApoE.Genotype           398
# ApoE.Risk               398
# MMSE                    444
# CDR                     379
# CASI                    580
# ABETA.2pep.corrected    195
# dtype: int64

# %%
johnson_consensus.isna().sum() / len(johnson_consensus)
# Out:
# SampleID                0.000000
# Age                     0.102326
# Sex                     0.102326
# PMI                     0.102326
# CERAD                   0.102326
# Braak                   0.131783
# Group                   0.000000
# Batch                   0.173643
# ApoE.Genotype           0.617054
# ApoE.Risk               0.617054
# MMSE                    0.688372
# CDR                     0.587597
# CASI                    0.899225
# ABETA.2pep.corrected    0.302326
# dtype: float64

# %%
johnson_consensus['MMSE'].unique()
# Out:
# array([nan,  6., 18.,  1.,  0., 17.,  4.,  3., 26., 22., 19., 11.,  5.,
#        14., 15., 10., 28., 27., 29., 30., 24.,  8., 25.,  7., 23., 16.,
#        20., 21., 12., 13.,  9.])

# %%
johnson_consensus['CDR'].unique()
# Out:
# array([nan, 1. , 2. , 3. , 4. , 5. , 0. , 0.5])

# %%
johnson_consensus['CASI'].unique()
# Out:
# array([46., 62., 69., 74., 45., 43., 66., 85., 78., 79., 87., 70., 80.,
#        86., 81., 68., 82., 73., 39., 88., 64., 75., 41., 60., 84., 37.,
#        91., 93., 95., 97., 98., 90., 96., 94., nan])

# %%
johnson_consensus['ABETA.2pep.corrected'].nunique()
# Out:
# 450

# %%
johnson_consensus['SampleID'].nunique()
# Out:
# 645

# %%
johnson_consensus['ApoE.Genotype'].unique()
# Out:
# array([nan, 'e3-4', 'e4-4', 'e3-3', 'e2-3', 'e2-4', 'e2-2'], dtype=object)

# %%
johnson_consensus['ApoE.Genotype'] = johnson_consensus['ApoE.Genotype'].str.split('-').str[0] + johnson_consensus['ApoE.Genotype'].str.split('-').str[1]
johnson_consensus.head(170)
# Out:
#              SampleID   Age  Sex   PMI  CERAD  Braak   Group      Batch  \
# 0        ACT.ad_act10  86.0  1.0  3.50    3.0    6.0      AD        NaN
# 1        ACT.ad_act62  90.0  0.0  3.50    3.0    6.0      AD        NaN
# 2        ACT.ad_act23  80.0  0.0  5.00    3.0    6.0      AD        NaN
# 3        ACT.ad_act52  90.0  0.0  3.85    3.0    5.0      AD        NaN
# 4        ACT.ad_act50  90.0  0.0  2.25    3.0    5.0      AD        NaN
# ..                ...   ...  ...   ...    ...    ...     ...        ...
# 165  BANNER.b4_043_29  77.0  1.0  3.50    3.0    6.0      AD  BANNER.b4
# 166  BANNER.b4_062_05  79.0  0.0  5.00    3.0    6.0      AD  BANNER.b4
# 167  BANNER.b4_063_15  68.0  0.0  4.16    3.0    6.0      AD  BANNER.b4
# 168  BANNER.b4_065_37  74.0  0.0  5.00    3.0    5.0      AD  BANNER.b4
# 169  BANNER.b4_066_08  90.0  1.0  4.50    3.0    5.0  AsymAD  BANNER.b4
#
#     ApoE.Genotype  ApoE.Risk  MMSE  CDR  CASI  ABETA.2pep.corrected
# ...

# %%
# johnson_consensus['y'] = johnson_consensus['Group'] == 'AD'

# %%
# from sklearn.model_selection import train_test_split

# df_train, df_test = train_test_split(df, test_size = 0.3, random_state=21, stratify=johnson_consensus['y'])

# %%
# from sklearn.neighbors import KNeighborsClassifier

# knn = KNeighborsClassifier(n_neighbors=7)
# knn.fit(X_train, y_train)

# %%
consensus_c = pd.read_csv('/Users/macbook/Desktop/data/johnson_20/Consensus/data/3.cleanDat.csv')
consensus_c.head(5)
# Out:
#      Unnamed: 0  MSSB.b1_1497_21  MSSB.b1_1515_07  MSSB.b1_1535_29  \
# 0  PRSS1|A6XGL3        -0.084136         0.545614        -0.164966
# 1  |CON__P01966         0.815052        -2.613076         0.899775
# 2  KRT6A|P02538         1.370773        -0.088139        -0.305636
# 3    ALB|P02768         0.478509        -0.659979        -0.197957
# 4  KRT16|P08779         0.625396        -0.560589        -0.436737
#
#    MSSB.b1_1542_12  MSSB.b1_1556_16  MSSB.b1_1566_41  MSSB.b1_1603_28  \
# 0         0.357562         0.187689        -0.216179        -0.241573
# 1         0.501162        -0.537529        -2.634919         0.212189
# 2         0.232194        -0.395279        -0.097268         0.012761
# 3        -0.489785         0.878138        -0.469044         1.509324
# 4        -0.331861        -0.881630        -1.181538         1.333567
#
#    MSSB.b1_1618_35  MSSB.b1_1622_06  ...  ACT.asym_act32  ACT.asym_act60  \
# ...

# %%
consensus_c.shape
# Out:
# (3334, 420)

# %%
consensus_c = consensus_c.T

# %%
consensus_c
# Out:
#                          0             1             2           3     \
# Unnamed: 0       PRSS1|A6XGL3  |CON__P01966  KRT6A|P02538  ALB|P02768
# MSSB.b1_1497_21     -0.084136      0.815052      1.370773    0.478509
# MSSB.b1_1515_07      0.545614     -2.613076     -0.088139   -0.659979
# MSSB.b1_1535_29     -0.164966      0.899775     -0.305636   -0.197957
# MSSB.b1_1542_12      0.357562      0.501162      0.232194   -0.489785
# ...                       ...           ...           ...         ...
# ACT.asym_act22       0.256264     -0.141987      4.991636    0.076562
# ACT.asym_act35      -0.126594       1.61923      0.757978   -0.136733
# ACT.asym_act54      -0.122528      0.370833      1.870587   -0.354786
# ACT.ad_act08        -0.215741     -0.278796      0.909667    0.288253
# ACT.asym_act30      -0.330976      4.133468       0.16132    0.309021
#
#                          4             5             6            7     \
# ...

# %%
first = consensus_c.iloc[0]
first
# Out:
# 0           PRSS1|A6XGL3
# 1           |CON__P01966
# 2           KRT6A|P02538
# 3             ALB|P02768
# 4           KRT16|P08779
#               ...
# 3329    CSNK1G3|Q9Y6M4-3
# 3330        HSPA8|A8K7Q2
# 3331         GNB1|B3KVK2
# 3332         MAP2|E7EV03
# 3333       MRPS22|P82650
# Name: Unnamed: 0, Length: 3334, dtype: object

# %%
consensus_c.columns = first
consensus_c.reset_index(inplace = True)
consensus_c
# Out:
# Unnamed: 0            index  PRSS1|A6XGL3  |CON__P01966  KRT6A|P02538  \
# 0                Unnamed: 0  PRSS1|A6XGL3  |CON__P01966  KRT6A|P02538
# 1           MSSB.b1_1497_21     -0.084136      0.815052      1.370773
# 2           MSSB.b1_1515_07      0.545614     -2.613076     -0.088139
# 3           MSSB.b1_1535_29     -0.164966      0.899775     -0.305636
# 4           MSSB.b1_1542_12      0.357562      0.501162      0.232194
# ..                      ...           ...           ...           ...
# 415          ACT.asym_act22      0.256264     -0.141987      4.991636
# 416          ACT.asym_act35     -0.126594       1.61923      0.757978
# 417          ACT.asym_act54     -0.122528      0.370833      1.870587
# 418            ACT.ad_act08     -0.215741     -0.278796      0.909667
# 419          ACT.asym_act30     -0.330976      4.133468       0.16132
#
# Unnamed: 0  ALB|P02768  KRT16|P08779  KRT10|P13645  |CON__P15636  KRT2|P35908  \
# ...

# %%
consensus_c.iloc[0]
consensus_c.drop(index =consensus_c.index[0], inplace = True)
consensus_c
# Out:
# Unnamed: 0            index PRSS1|A6XGL3 |CON__P01966 KRT6A|P02538 ALB|P02768  \
# 1           MSSB.b1_1497_21    -0.084136     0.815052     1.370773   0.478509
# 2           MSSB.b1_1515_07     0.545614    -2.613076    -0.088139  -0.659979
# 3           MSSB.b1_1535_29    -0.164966     0.899775    -0.305636  -0.197957
# 4           MSSB.b1_1542_12     0.357562     0.501162     0.232194  -0.489785
# 5           MSSB.b1_1556_16     0.187689    -0.537529    -0.395279   0.878138
# ..                      ...          ...          ...          ...        ...
# 415          ACT.asym_act22     0.256264    -0.141987     4.991636   0.076562
# 416          ACT.asym_act35    -0.126594      1.61923     0.757978  -0.136733
# 417          ACT.asym_act54    -0.122528     0.370833     1.870587  -0.354786
# 418            ACT.ad_act08    -0.215741    -0.278796     0.909667   0.288253
# 419          ACT.asym_act30    -0.330976     4.133468      0.16132   0.309021
#
# ...

# %%
consensus_c.rename(columns={'index': 'SampleID'}, inplace=True)
consensus_c
# Out:
# Unnamed: 0         SampleID PRSS1|A6XGL3 |CON__P01966 KRT6A|P02538 ALB|P02768  \
# 1           MSSB.b1_1497_21    -0.084136     0.815052     1.370773   0.478509
# 2           MSSB.b1_1515_07     0.545614    -2.613076    -0.088139  -0.659979
# 3           MSSB.b1_1535_29    -0.164966     0.899775    -0.305636  -0.197957
# 4           MSSB.b1_1542_12     0.357562     0.501162     0.232194  -0.489785
# 5           MSSB.b1_1556_16     0.187689    -0.537529    -0.395279   0.878138
# ..                      ...          ...          ...          ...        ...
# 415          ACT.asym_act22     0.256264    -0.141987     4.991636   0.076562
# 416          ACT.asym_act35    -0.126594      1.61923     0.757978  -0.136733
# 417          ACT.asym_act54    -0.122528     0.370833     1.870587  -0.354786
# 418            ACT.ad_act08    -0.215741    -0.278796     0.909667   0.288253
# 419          ACT.asym_act30    -0.330976     4.133468      0.16132   0.309021
#
# ...

# %%
consensus_c['SampleID'].nunique()
# Out:
# 419

# %%
df = pd.merge(johnson_consensus, consensus_c ,on='SampleID', how='right')
df['y'] = df['Group'] == 'AD'
# df.drop(columns=['SampleID'], inplace=True)
print(df.shape)
df.head(170)
# Out:
# (419, 3349)
#              SampleID   Age  Sex        PMI  CERAD  Braak   Group      Batch  \
# 0     MSSB.b1_1497_21  90.0  0.0   2.916667    3.0    6.0      AD    MSSB.b1
# 1     MSSB.b1_1515_07  90.0  0.0   8.416667    3.0    6.0      AD    MSSB.b1
# 2     MSSB.b1_1535_29  90.0  0.0  22.666667    3.0    6.0      AD    MSSB.b1
# 3     MSSB.b1_1542_12  90.0  0.0  11.000000    3.0    5.0      AD    MSSB.b1
# 4     MSSB.b1_1556_16  90.0  0.0   5.333333    3.0    6.0      AD    MSSB.b1
# ..                ...   ...  ...        ...    ...    ...     ...        ...
# 165  BANNER.b1_025_30  87.0  0.0   3.330000    3.0    5.0      AD  BANNER.b1
# 166  BANNER.b1_042_03  80.0  1.0   3.160000    3.0    6.0      AD  BANNER.b1
# 167  BANNER.b1_049_49  89.0  1.0   3.000000    2.0    6.0  AsymAD  BANNER.b1
# 168  BANNER.b1_051_36  72.0  1.0   3.000000    3.0    5.0      AD  BANNER.b1
# 169  BANNER.b1_054_46  88.0  0.0   3.000000    3.0    5.0      AD  BANNER.b1
#
# ...

# %%
for col in df.columns:
    try:
        df[col] = df[col].astype(float)
    except ValueError:
        print(col)
        pass
# Out:
# SampleID
# Group
# Batch
# ApoE.Genotype

# %%
df['ApoE.Genotype'] = df['ApoE.Genotype'].str[1:]
df['ApoE.Genotype'].unique()
# Out:
# array([nan, '33', '34', '44', '24', '23', '22'], dtype=object)

# %%
# df['ApoE.Genotype'] = df['ApoE.Genotype'].str[1:]
# df['ApoE.Genotype'] = df['ApoE.Genotype'].astype(int)
# df.head(170)

# %%
df.dtypes
# Out:
# SampleID          object
# Age              float64
# Sex              float64
# PMI              float64
# CERAD            float64
#                   ...
# HSPA8|A8K7Q2     float64
# GNB1|B3KVK2      float64
# MAP2|E7EV03      float64
# MRPS22|P82650    float64
# y                float64
# Length: 3349, dtype: object

# %%
df.isnull().sum()
# Out:
# SampleID           0
# Age                0
# Sex                0
# PMI                0
# CERAD              0
#                 ...
# HSPA8|A8K7Q2     175
# GNB1|B3KVK2      194
# MAP2|E7EV03      186
# MRPS22|P82650    179
# y                  0
# Length: 3349, dtype: int64

# %%
df.isnull().sum(axis=1).sort_values()
# Out:
# 194     75
# 171     75
# 174     77
# 177     77
# 224     77
#       ...
# 151    464
# 154    474
# 329    476
# 352    539
# 156    555
# Length: 419, dtype: int64

# %%
df['ApoE.Genotype'].isna().sum()
# Out:
# 216

# %%
df['ApoE.Genotype'].unique()
# Out:
# array([nan, '33', '34', '44', '24', '23', '22'], dtype=object)

# %%
# df['ApoE.Genotype'] = df['ApoE.Genotype'].str.split('-').str[0] + df['ApoE.Genotype'].str.split('-').str[1] 
# df.head(170)

# %%
df['ApoE.Genotype'].iloc[165]
# Out:
# '33'

# %%
df['ApoE.Risk'].unique()
# Out:
# array([nan,  0.,  1.,  2., -1., -2.])

# %%
df['Batch'].unique()
# Out:
# array(['MSSB.b1', 'MSSB.b2', 'MSSB.b3', 'MSSB.b4', 'MSSB.b5', 'MSSB.b6',
#        'MSSB.b7', 'BANNER.b1', 'BANNER.b2', 'BANNER.b3', 'BANNER.b4', nan],
#       dtype=object)

# %%
df['Group'].unique()
# Out:
# array(['AD', 'AsymAD', 'Control'], dtype=object)

# %%
df.head(170)
# Out:
#              SampleID   Age  Sex        PMI  CERAD  Braak   Group      Batch  \
# 0     MSSB.b1_1497_21  90.0  0.0   2.916667    3.0    6.0      AD    MSSB.b1
# 1     MSSB.b1_1515_07  90.0  0.0   8.416667    3.0    6.0      AD    MSSB.b1
# 2     MSSB.b1_1535_29  90.0  0.0  22.666667    3.0    6.0      AD    MSSB.b1
# 3     MSSB.b1_1542_12  90.0  0.0  11.000000    3.0    5.0      AD    MSSB.b1
# 4     MSSB.b1_1556_16  90.0  0.0   5.333333    3.0    6.0      AD    MSSB.b1
# ..                ...   ...  ...        ...    ...    ...     ...        ...
# 165  BANNER.b1_025_30  87.0  0.0   3.330000    3.0    5.0      AD  BANNER.b1
# 166  BANNER.b1_042_03  80.0  1.0   3.160000    3.0    6.0      AD  BANNER.b1
# 167  BANNER.b1_049_49  89.0  1.0   3.000000    2.0    6.0  AsymAD  BANNER.b1
# 168  BANNER.b1_051_36  72.0  1.0   3.000000    3.0    5.0      AD  BANNER.b1
# 169  BANNER.b1_054_46  88.0  0.0   3.000000    3.0    5.0      AD  BANNER.b1
#
# ...

# %%
df.drop(columns=['SampleID', 'Group', 'Batch'], inplace=True)
df.head(170)
# Out:
#       Age  Sex        PMI  CERAD  Braak ApoE.Genotype  ApoE.Risk  MMSE  CDR  \
# 0    90.0  0.0   2.916667    3.0    6.0           NaN        NaN   NaN  4.0
# 1    90.0  0.0   8.416667    3.0    6.0           NaN        NaN   NaN  4.0
# 2    90.0  0.0  22.666667    3.0    6.0           NaN        NaN   NaN  3.0
# 3    90.0  0.0  11.000000    3.0    5.0           NaN        NaN   NaN  5.0
# 4    90.0  0.0   5.333333    3.0    6.0           NaN        NaN   NaN  5.0
# ..    ...  ...        ...    ...    ...           ...        ...   ...  ...
# 165  87.0  0.0   3.330000    3.0    5.0            33        0.0  17.0  NaN
# 166  80.0  1.0   3.160000    3.0    6.0            34        1.0   1.0  NaN
# 167  89.0  1.0   3.000000    2.0    6.0            34        1.0  25.0  NaN
# 168  72.0  1.0   3.000000    3.0    5.0            44        2.0   0.0  NaN
# 169  88.0  0.0   3.000000    3.0    5.0            34        1.0   3.0  NaN
#
# ...

# %%
# Missung values imputatio with median
df[df.columns] = df[df.columns].apply(pd.to_numeric, errors = 'coerce')
df = df.fillna(df.median())
df
# Out:
#       Age  Sex        PMI  CERAD  Braak  ApoE.Genotype  ApoE.Risk  MMSE  CDR  \
# 0    90.0  0.0   2.916667    3.0    6.0           33.0        0.0  24.0  4.0
# 1    90.0  0.0   8.416667    3.0    6.0           33.0        0.0  24.0  4.0
# 2    90.0  0.0  22.666667    3.0    6.0           33.0        0.0  24.0  3.0
# 3    90.0  0.0  11.000000    3.0    5.0           33.0        0.0  24.0  5.0
# 4    90.0  0.0   5.333333    3.0    6.0           33.0        0.0  24.0  5.0
# ..    ...  ...        ...    ...    ...            ...        ...   ...  ...
# 414  89.0  0.0   2.500000    3.0    5.0           33.0        0.0  24.0  2.0
# 415  90.0  0.0  12.000000    2.0    3.0           33.0        0.0  24.0  2.0
# 416  90.0  1.0   2.833333    2.0    3.0           33.0        0.0  24.0  2.0
# 417  87.0  1.0   4.500000    3.0    6.0           33.0        0.0  24.0  2.0
# 418  90.0  1.0   5.500000    2.0    3.0           33.0        0.0  24.0  2.0
#
# ...

# %%
from sklearn.impute import KNNImputer

knn_imp = KNNImputer(n_neighbors = 5, weights = 'distance')
imputed_df = knn_imp.fit_transform(df)

df_knn_filled = pd.DataFrame(imputed_df, columns = df.columns)
df_knn_filled
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(strategy='median')
imp_mean.fit_transform(df)

df_imputed = pd.DataFrame(imp_mean.fit_transform(df), columns = df.columns)
df_imputed
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
# MICE imputation
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imputer = IterativeImputer(max_iter=10, random_state=0)

imputer.fit(df)
imputed_values = imputer.transform(df)

df_mice = pd.DataFrame(imputed_values, columns = df.columns)
df_mice
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
df_mice

# %%
# df['ApoE.Genotype'] = df['ApoE.Genotype'].str[1:]
# df['ApoE.Genotype'] = df['ApoE.Genotype'].astype(int)

# %%
# We leave only good columns - without Nan
# a = df.isnull().sum()
# good_cols = a[a == 0].index

# %%
# df = df[good_cols]

# %%
import itertools
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score, roc_curve, auc
   
def roc_auc_pic(y_hat_test, y_test):    
    fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_hat_test)
    roc_auc_test = roc_auc_score(y_test, y_hat_test)

    matplotlib.rcParams['figure.figsize'] = (8, 8)
    plt.plot(fpr_test, tpr_test, label='Test ROC AUC {0}'.format(roc_auc_test))
    plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6))
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.show() 
    pass

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size = 0.3, random_state=42, stratify=df['y'])
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
X_train = df_train.drop(columns=['y'])
X_test = df_test.drop(columns=['y'])
y_train = df_train['y']
y_test = df_test['y'].values

# %%
X_train
# Out:
#       Age  Sex        PMI  CERAD  Braak  ApoE.Genotype  ApoE.Risk  MMSE  CDR  \
# 304  90.0  0.0   2.430000    3.0    5.0           34.0        1.0  22.0  2.0
# 78   90.0  0.0   6.283333    3.0    6.0           33.0        0.0  24.0  3.0
# 301  90.0  1.0   4.500000    3.0    5.0           33.0        0.0  24.0  2.0
# 145  72.0  1.0   9.833333    3.0    5.0           33.0        0.0  24.0  1.0
# 166  80.0  1.0   3.160000    3.0    6.0           34.0        1.0   1.0  2.0
# ..    ...  ...        ...    ...    ...            ...        ...   ...  ...
# 333  72.0  1.0  10.000000    0.0    2.0           33.0        0.0  24.0  2.0
# 398  84.0  1.0   4.500000    0.0    2.0           33.0        0.0  24.0  2.0
# 136  62.0  1.0  16.483333    3.0    6.0           33.0        0.0  24.0  1.0
# 189  87.0  0.0   2.500000    2.0    3.0           23.0       -1.0  26.0  2.0
# 379  77.0  1.0   6.000000    3.0    6.0           33.0        0.0  24.0  2.0
#
# ...

# %%
X_test
# Out:
#       Age  Sex       PMI  CERAD  Braak  ApoE.Genotype  ApoE.Risk  MMSE  CDR  \
# 147  69.0  1.0  4.250000    0.0    1.0           33.0        0.0  24.0  0.5
# 392  90.0  1.0  3.333300    3.0    6.0           33.0        0.0  24.0  2.0
# 57   90.0  0.0  8.716667    3.0    6.0           33.0        0.0  24.0  3.0
# 308  88.0  0.0  2.000000    2.0    3.0           34.0        1.0  30.0  2.0
# 13   90.0  1.0  2.000000    3.0    3.0           33.0        0.0  24.0  2.0
# ..    ...  ...       ...    ...    ...            ...        ...   ...  ...
# 265  89.0  1.0  2.200000    3.0    5.0           23.0       -1.0  21.0  2.0
# 389  90.0  0.0  5.000000    3.0    5.0           33.0        0.0  24.0  2.0
# 357  83.0  1.0  6.000000    2.0    4.0           33.0        0.0  24.0  2.0
# 178  76.0  0.0  2.580000    3.0    5.0           44.0        2.0   5.0  2.0
# 164  76.0  1.0  4.000000    3.0    5.0           44.0        2.0   0.0  2.0
#
# ...

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=15, weights='distance')
knn.fit(X_train_norm, y_train)

y_knn_predict = knn.predict(X_test_norm)
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
print(classification_report(y_test,y_knn_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.86      0.83        57
#          1.0       0.88      0.83      0.85        69
#
#     accuracy                           0.84       126
#    macro avg       0.84      0.84      0.84       126
# weighted avg       0.84      0.84      0.84       126

# %%
print(roc_auc_score(y_test, y_knn_predict))
# Out:
# 0.8428680396643784

# %%
roc_auc_pic(y_knn_predict, y_test)

# %%
from sklearn.model_selection import GridSearchCV

knn_2 = KNeighborsClassifier()
params = {'n_neighbors': range(1, 17), 'weights': ['uniform', 'distance']}
grid_knn = GridSearchCV(knn_2, params, scoring="roc_auc", cv=7)
grid_knn.fit(X_train_norm, y_train)
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
grid_knn.best_score_
# Out:
# 0.8516762921797246

# %%
grid_knn.best_params_
# Out:
# {'n_neighbors': 14, 'weights': 'distance'}

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier()
tree.fit(X_train_norm, y_train)
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# DecisionTreeClassifier()

# %%
y_tree_predict = tree.predict(X_test_norm)
print(roc_auc_score(y_test, y_tree_predict))
# Out:
# 0.9126620900076278

# %%
roc_auc_pic(y_tree_predict, y_test)

# %%
print(classification_report(y_test,y_tree_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.91      0.90        57
#          1.0       0.93      0.91      0.92        69
#
#     accuracy                           0.91       126
#    macro avg       0.91      0.91      0.91       126
# weighted avg       0.91      0.91      0.91       126

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 8)
classifier.fit(X_train, y_train)
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
from sklearn.metrics import classification_report

# %%
rfc_pred = classifier.predict(X_test)
print(classification_report(y_test,rfc_pred))
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.88      0.83        57
# ...

# %%
print(roc_auc_score(y_test, rfc_pred))
# Out:
# 0.8443935926773456

# %%
roc_auc_pic(rfc_pred, y_test)
