# %%
import pandas as pd               
import numpy as np                
import matplotlib.pyplot as plt   
import matplotlib

# %%
# Cohort 2. Cohort_2_96-sample_biomarker_defined_Asymptomatic_AD_Symptomatic_AD_and_Controls
# GIS - global internal standard

# %%
johnson_csf2 = pd.read_csv('/Users/macbook/Desktop/data/johnson_20/CSF/Cohort_2_96-sample_biomarker_defined_Asymptomatic_AD_Symptomatic_AD_and_Controls/data/0.Traits.csv')
johnson_csf2
# Out:
#     batch.channel   Age  Sex  Race  Education ClinicalGroup  \
# 0         b1.127N   NaN  NaN   NaN        NaN           GIS
# 1         b1.128N  56.0  0.0   4.0       18.0        NORMAL
# 2         b1.128C  76.0  1.0   4.0       14.0           MCI
# 3         b1.129N  71.0  1.0   2.0       16.0        NORMAL
# 4         b1.129C  81.0  1.0   2.0       16.0           MCI
# ..            ...   ...  ...   ...        ...           ...
# 103      b12.129C  58.0  1.0   4.0       16.0        NORMAL
# 104      b12.130N  66.0  1.0   4.0       15.0        NORMAL
# 105      b12.130C  78.0  0.0   4.0       18.0           MCI
# 106      b12.131N  67.0  1.0   4.0       12.0        NORMAL
# 107      b12.131C  76.0  1.0   2.0       14.0           MCI
#
#      BiomarkerGrouping  FamHistAD  Moca        Ab42        Tau        ptau  \
# 0                    0        NaN   NaN         NaN        NaN         NaN
# 1                    3        1.0  28.0  301.000000   44.00000          14
# ...

# %%
johnson_csf2.rename(columns = {'batch.channel':'SampleID'}, inplace = True)
johnson_csf2
# Out:
#      SampleID   Age  Sex  Race  Education ClinicalGroup  BiomarkerGrouping  \
# 0     b1.127N   NaN  NaN   NaN        NaN           GIS                  0
# 1     b1.128N  56.0  0.0   4.0       18.0        NORMAL                  3
# 2     b1.128C  76.0  1.0   4.0       14.0           MCI                  1
# 3     b1.129N  71.0  1.0   2.0       16.0        NORMAL                  2
# 4     b1.129C  81.0  1.0   2.0       16.0           MCI                  1
# ..        ...   ...  ...   ...        ...           ...                ...
# 103  b12.129C  58.0  1.0   4.0       16.0        NORMAL                  2
# 104  b12.130N  66.0  1.0   4.0       15.0        NORMAL                  3
# 105  b12.130C  78.0  0.0   4.0       18.0           MCI                  1
# 106  b12.131N  67.0  1.0   4.0       12.0        NORMAL                  3
# 107  b12.131C  76.0  1.0   2.0       14.0           MCI                  1
#
#      FamHistAD  Moca        Ab42        Tau        ptau  AB.TAUratio
# ...

# %%
johnson_csf2.isnull().sum()
# Out:
# SampleID              0
# Age                  12
# Sex                  12
# Race                 12
# Education            12
# ClinicalGroup         0
# BiomarkerGrouping     0
# FamHistAD            22
# Moca                 13
# Ab42                 12
# Tau                  12
# ptau                 12
# AB.TAUratio          12
# dtype: int64

# %%
johnson_csf2.isnull().sum() / len(johnson_csf2)
# Out:
# SampleID             0.000000
# Age                  0.111111
# Sex                  0.111111
# Race                 0.111111
# Education            0.111111
# ClinicalGroup        0.000000
# BiomarkerGrouping    0.000000
# FamHistAD            0.203704
# Moca                 0.120370
# Ab42                 0.111111
# Tau                  0.111111
# ptau                 0.111111
# AB.TAUratio          0.111111
# dtype: float64

# %%
johnson_csf2['ClinicalGroup'].unique()
# Out:
# array(['GIS', 'NORMAL', 'MCI', 'AD'], dtype=object)

# %%
johnson_csf2.nunique()
# Out:
# SampleID             108
# Age                   32
# Sex                    2
# Race                   3
# Education             14
# ClinicalGroup          4
# BiomarkerGrouping      4
# FamHistAD              2
# Moca                  18
# Ab42                  82
# Tau                   67
# ptau                  42
# AB.TAUratio           95
# dtype: int64

# %%
johnson_csf2.dtypes
# Out:
# SampleID              object
# Age                  float64
# Sex                  float64
# Race                 float64
# Education            float64
# ClinicalGroup         object
# BiomarkerGrouping      int64
# FamHistAD            float64
# Moca                 float64
# Ab42                 float64
# Tau                  float64
# ptau                  object
# AB.TAUratio          float64
# dtype: object

# %%
csf2_c = pd.read_csv('/Users/macbook/Desktop/data/johnson_20/CSF/Cohort_2_96-sample_biomarker_defined_Asymptomatic_AD_Symptomatic_AD_and_Controls/data/3.cleanDat.csv')
csf2_c.head(7)
# Out:
#        Unnamed: 0   b1.128N   b1.128C   b1.129N   b1.129C   b1.130N   b1.130C  \
# 0    GSTO1|Q5TA01  0.095373 -0.081900 -0.171203 -0.186333 -0.326462  0.304410
# 1      MT3|P25713 -0.568629 -0.239242 -0.143066  0.045706  0.156676 -0.510534
# 2    NFASC|O94856  0.013841 -0.255042  0.025239 -0.039496 -0.092792  0.160740
# 3    ALDOA|P04075  0.249106  0.491278  0.058084  0.125236 -0.018758  0.151235
# 4  CNTNAP2|Q9UHC6  0.508997  1.020343  0.615364  0.485645  1.007894  0.599754
# 5    LSAMP|Q13449 -0.079810 -0.195030 -0.073254 -0.081800  0.230780 -0.059715
# 6    PARK7|K7ELW0  0.261402  0.973285  0.571139  0.072150 -0.374054  0.162275
#
#     b1.131N   b1.131C   b2.128N  ...  b11.131N  b11.131C  b12.128N  b12.128C  \
# 0 -0.035390 -0.191167       NaN  ...       NaN       NaN -0.082292 -0.585916
# 1  0.254016 -0.045276 -0.519862  ... -0.175078 -0.264906 -0.285581 -0.261531
# 2  0.059048  0.023951  0.013015  ... -0.101867  0.256013 -0.465388  0.109140
# ...

# %%
csf2_c = csf2_c.T

# %%
csf2_c
# Out:
#                      0           1             2             3    \
# Unnamed: 0  GSTO1|Q5TA01  MT3|P25713  NFASC|O94856  ALDOA|P04075
# b1.128N         0.095373   -0.568629      0.013841      0.249106
# b1.128C          -0.0819   -0.239242     -0.255042      0.491278
# b1.129N        -0.171203   -0.143066      0.025239      0.058084
# b1.129C        -0.186333    0.045706     -0.039496      0.125236
# ...                  ...         ...           ...           ...
# b12.129C        0.280409   -0.678547     -0.165711     -0.049222
# b12.130N        0.106271   -0.586512     -0.060765     -0.171137
# b12.130C       -0.394703    0.142513      0.022714      0.392166
# b12.131N       -0.328968   -0.146377     -0.310426      0.018235
# b12.131C        0.188262   -0.223448     -0.146372      0.324915
#
#                        4             5             6             7    \
# Unnamed: 0  CNTNAP2|Q9UHC6  LSAMP|Q13449  PARK7|K7ELW0  YWHAZ|P63104
# ...

# %%
first = csf2_c.iloc[0]
csf2_c.drop('Unnamed: 0', inplace=True)
first
# Out:
# 0        GSTO1|Q5TA01
# 1          MT3|P25713
# 2        NFASC|O94856
# 3        ALDOA|P04075
# 4      CNTNAP2|Q9UHC6
#             ...
# 787      PEBP4|Q96S96
# 788       GMFB|P60983
# 789      SCRG1|O75711
# 790     MINPP1|Q9UNW1
# 791      NUCB1|Q02818
# Name: Unnamed: 0, Length: 792, dtype: object

# %%
csf2_c.columns = first
csf2_c.reset_index(inplace = True)
csf2_c
# Out:
# Unnamed: 0     index GSTO1|Q5TA01 MT3|P25713 NFASC|O94856 ALDOA|P04075  \
# 0            b1.128N     0.095373  -0.568629     0.013841     0.249106
# 1            b1.128C      -0.0819  -0.239242    -0.255042     0.491278
# 2            b1.129N    -0.171203  -0.143066     0.025239     0.058084
# 3            b1.129C    -0.186333   0.045706    -0.039496     0.125236
# 4            b1.130N    -0.326462   0.156676    -0.092792    -0.018758
# ..               ...          ...        ...          ...          ...
# 91          b12.129C     0.280409  -0.678547    -0.165711    -0.049222
# 92          b12.130N     0.106271  -0.586512    -0.060765    -0.171137
# 93          b12.130C    -0.394703   0.142513     0.022714     0.392166
# 94          b12.131N    -0.328968  -0.146377    -0.310426     0.018235
# 95          b12.131C     0.188262  -0.223448    -0.146372     0.324915
#
# Unnamed: 0 CNTNAP2|Q9UHC6 LSAMP|Q13449 PARK7|K7ELW0 YWHAZ|P63104  \
# ...

# %%
csf2_c.rename(columns={'index':'SampleID'}, inplace = True)
csf2_c
# Out:
# Unnamed: 0  SampleID GSTO1|Q5TA01 MT3|P25713 NFASC|O94856 ALDOA|P04075  \
# 0            b1.128N     0.095373  -0.568629     0.013841     0.249106
# 1            b1.128C      -0.0819  -0.239242    -0.255042     0.491278
# 2            b1.129N    -0.171203  -0.143066     0.025239     0.058084
# 3            b1.129C    -0.186333   0.045706    -0.039496     0.125236
# 4            b1.130N    -0.326462   0.156676    -0.092792    -0.018758
# ..               ...          ...        ...          ...          ...
# 91          b12.129C     0.280409  -0.678547    -0.165711    -0.049222
# 92          b12.130N     0.106271  -0.586512    -0.060765    -0.171137
# 93          b12.130C    -0.394703   0.142513     0.022714     0.392166
# 94          b12.131N    -0.328968  -0.146377    -0.310426     0.018235
# 95          b12.131C     0.188262  -0.223448    -0.146372     0.324915
#
# Unnamed: 0 CNTNAP2|Q9UHC6 LSAMP|Q13449 PARK7|K7ELW0 YWHAZ|P63104  \
# ...

# %%
df = pd.merge(johnson_csf2, csf2_c, on = 'SampleID', how = 'right')
df['y'] = df['ClinicalGroup'] == 'AD'
df.drop(columns = ['SampleID', 'ClinicalGroup'], inplace = True )
df
# Out:
#      Age  Sex  Race  Education  BiomarkerGrouping  FamHistAD  Moca  \
# 0   56.0  0.0   4.0       18.0                  3        1.0  28.0
# 1   76.0  1.0   4.0       14.0                  1        NaN  22.0
# 2   71.0  1.0   2.0       16.0                  2        1.0  28.0
# 3   81.0  1.0   2.0       16.0                  1        1.0  18.0
# 4   63.0  0.0   2.0       14.0                  3        0.0  29.0
# ..   ...  ...   ...        ...                ...        ...   ...
# 91  58.0  1.0   4.0       16.0                  2        0.0  29.0
# 92  66.0  1.0   4.0       15.0                  3        0.0  22.0
# 93  78.0  0.0   4.0       18.0                  1        0.0  12.0
# 94  67.0  1.0   4.0       12.0                  3        0.0  23.0
# 95  76.0  1.0   2.0       14.0                  1        0.0  24.0
#
#           Ab42        Tau        ptau  ...  PCSK2|P16519 VSIG4|Q9Y279  \
# 0   301.000000   44.00000          14  ...      0.240971    -0.422962
# ...

# %%
df.dtypes
# Out:
# Age                  float64
# Sex                  float64
# Race                 float64
# Education            float64
# BiomarkerGrouping      int64
#                       ...
# GMFB|P60983           object
# SCRG1|O75711          object
# MINPP1|Q9UNW1         object
# NUCB1|Q02818          object
# y                       bool
# Length: 804, dtype: object

# %%
for col in df.columns:
    try:
        df[col] = df[col].astype(float)
    except ValueError:
        print(col)
        pass
# Out:
# ptau

# %%
df['ptau'].unique()
# Out:
# array(['14', '38.8895627', '20', '31', '10', '26', '12', '13', '9', '54',
#        '29', '52', '51', '15', '17', '73.69731811', '44', '32', '22', '6',
#        '8', '77', '29.65605586', '7', '30', '16', '11', '25',
#        '50.43173695', '23', '57.31011061', '21', '35.98716154',
#        '59.32894261', '56.16636255', '28', '27', '19.07196663',
#        '71.11238316', '18', '< 4.5', '40'], dtype=object)

# %%
df['ptau'].replace('< 4.5' , '4.5', inplace = True)

# %%
df
# Out:
#      Age  Sex  Race  Education  BiomarkerGrouping  FamHistAD  Moca  \
# 0   56.0  0.0   4.0       18.0                3.0        1.0  28.0
# 1   76.0  1.0   4.0       14.0                1.0        NaN  22.0
# 2   71.0  1.0   2.0       16.0                2.0        1.0  28.0
# 3   81.0  1.0   2.0       16.0                1.0        1.0  18.0
# 4   63.0  0.0   2.0       14.0                3.0        0.0  29.0
# ..   ...  ...   ...        ...                ...        ...   ...
# 91  58.0  1.0   4.0       16.0                2.0        0.0  29.0
# 92  66.0  1.0   4.0       15.0                3.0        0.0  22.0
# 93  78.0  0.0   4.0       18.0                1.0        0.0  12.0
# 94  67.0  1.0   4.0       12.0                3.0        0.0  23.0
# 95  76.0  1.0   2.0       14.0                1.0        0.0  24.0
#
#           Ab42        Tau        ptau  ...  PCSK2|P16519  VSIG4|Q9Y279  \
# 0   301.000000   44.00000          14  ...      0.240971     -0.422962
# ...

# %%
df.shape
# Out:
# (96, 804)

# %%
df.isna().sum()
# Out:
# Age                   0
# Sex                   0
# Race                  0
# Education             0
# BiomarkerGrouping     0
#                      ..
# GMFB|P60983          18
# SCRG1|O75711          0
# MINPP1|Q9UNW1        16
# NUCB1|Q02818          0
# y                     0
# Length: 804, dtype: int64

# %%
df.isna().sum() / len(df)
# Out:
# Age                  0.000000
# Sex                  0.000000
# Race                 0.000000
# Education            0.000000
# BiomarkerGrouping    0.000000
#                        ...
# GMFB|P60983          0.187500
# SCRG1|O75711         0.000000
# MINPP1|Q9UNW1        0.166667
# NUCB1|Q02818         0.000000
# y                    0.000000
# Length: 804, dtype: float64

# %%
df.isna().sum(axis = 1).sort_values()
# Out:
# 52     32
# 55     33
# 49     34
# 50     34
# 48     35
#      ...
# 88    121
# 22    122
# 16    122
# 20    123
# 23    128
# Length: 96, dtype: int64

# %%
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(strategy='median')
imp_mean.fit_transform(df)

df_imputed = pd.DataFrame(imp_mean.fit_transform(df), columns = df.columns)
df_imputed
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
df_imputed.isna().sum()
# Out:
# Age                  0
# Sex                  0
# Race                 0
# Education            0
# BiomarkerGrouping    0
#                     ..
# GMFB|P60983          0
# SCRG1|O75711         0
# MINPP1|Q9UNW1        0
# NUCB1|Q02818         0
# y                    0
# Length: 804, dtype: int64

# %%
# #X - known columns without 
# from sklearn.model_selection import train_test_split
# df_train, df_test = train_test_split(df, test_size = 0.3, random_state = 42)

# imp_X_train = df_train(columns = ['Age', 'Sex', 'Race', 'Education', 'BiomarkerGroping'])
# imp_X_test = df_test(columns = ['Age', 'Sex', 'Race', 'Education', 'BiomarkerGroping'])
# imp_y_train = df_train.drop(columns = ['Age', 'Sex', 'Race', 'Education', 'BiomarkerGroping'])
# imp_y_test = df_test.drop(columns = ['Age', 'Sex', 'Race', 'Education', 'BiomarkerGroping'])

# from sklearn.impute import KNNImputer

# knn_imp = KNNImputer(n_neighbors = 5, weights = 'distance')
# knn_imp.fit_transform(df)

# %%
# Missung values imputation with median
df[df.columns] = df[df.columns].apply(pd.to_numeric, errors = 'coerce')
df = df.fillna(df.median())
df
# Out:
#      Age  Sex  Race  Education  BiomarkerGrouping  FamHistAD  Moca  \
# 0   56.0  0.0   4.0       18.0                3.0        1.0  28.0
# 1   76.0  1.0   4.0       14.0                1.0        0.0  22.0
# 2   71.0  1.0   2.0       16.0                2.0        1.0  28.0
# 3   81.0  1.0   2.0       16.0                1.0        1.0  18.0
# 4   63.0  0.0   2.0       14.0                3.0        0.0  29.0
# ..   ...  ...   ...        ...                ...        ...   ...
# 91  58.0  1.0   4.0       16.0                2.0        0.0  29.0
# 92  66.0  1.0   4.0       15.0                3.0        0.0  22.0
# 93  78.0  0.0   4.0       18.0                1.0        0.0  12.0
# 94  67.0  1.0   4.0       12.0                3.0        0.0  23.0
# 95  76.0  1.0   2.0       14.0                1.0        0.0  24.0
#
#           Ab42        Tau       ptau  ...  PCSK2|P16519  VSIG4|Q9Y279  \
# 0   301.000000   44.00000  14.000000  ...      0.240971     -0.422962
# ...

# %%
df.isna().sum()
# Out:
# Age                  0
# Sex                  0
# Race                 0
# Education            0
# BiomarkerGrouping    0
#                     ..
# GMFB|P60983          0
# SCRG1|O75711         0
# MINPP1|Q9UNW1        0
# NUCB1|Q02818         0
# y                    0
# Length: 804, dtype: int64

# %%
from sklearn.impute import KNNImputer

knn_imp = KNNImputer(n_neighbors = 7, weights = 'distance')
imputed_df = knn_imp.fit_transform(df)

df_knn_filled = pd.DataFrame(imputed_df, columns = df.columns)
df_knn_filled
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
# MICE imputation
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# df_copy = df.copy()
# missing_mask = df_copy.isna()

imputer = IterativeImputer(max_iter=10, random_state=0)
# imputed_values = imputer.fit_transform(df)

# df_copy[missing_mask] = imputed_values[missing_mask]
imputer.fit(df)
imputed_values = imputer.transform(df)
df_mice = pd.DataFrame(imputed_values, columns = df.columns)
df_mice
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
imputed_values
# Out:
# array([[ 5.60000000e+01,  0.00000000e+00,  4.00000000e+00, ...,
#         -4.22737534e-01,  4.21177983e-01,  0.00000000e+00],
#        [ 7.60000000e+01,  1.00000000e+00,  4.00000000e+00, ...,
#         -6.07688906e-01,  4.15377059e-01,  0.00000000e+00],
#        [ 7.10000000e+01,  1.00000000e+00,  2.00000000e+00, ...,
#         -4.03206135e-01,  4.90671158e-01,  0.00000000e+00],
#        ...,
#        [ 7.80000000e+01,  0.00000000e+00,  4.00000000e+00, ...,
#         -6.78886834e-01,  1.84334662e-01,  0.00000000e+00],
#        [ 6.70000000e+01,  1.00000000e+00,  4.00000000e+00, ...,
#         -3.55680448e-01,  6.97060065e-02,  0.00000000e+00],
#        [ 7.60000000e+01,  1.00000000e+00,  2.00000000e+00, ...,
#         -9.49077290e-02,  4.96537695e-01,  0.00000000e+00]])

# %%
df_mice.isna().sum()
# Out:
# Age                  0
# Sex                  0
# Race                 0
# Education            0
# BiomarkerGrouping    0
#                     ..
# GMFB|P60983          0
# SCRG1|O75711         0
# MINPP1|Q9UNW1        0
# NUCB1|Q02818         0
# y                    0
# Length: 804, dtype: int64

# %%
# We leave only good columns - without Nan
# sum_null = df.isnull().sum()
# good_cols = sum_null[sum_null == 0].index
# good_cols

# %%
# df = df[good_cols]

# %%
df.shape
# Out:
# (96, 804)

# %%
import itertools
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score, roc_curve, auc
   
def roc_auc_pic(y_hat_test, y_test):    
    fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_hat_test)
    roc_auc_test = roc_auc_score(y_test, y_hat_test)
    matplotlib.rcParams['figure.figsize'] = (8, 8)
    plt.plot(fpr_test, tpr_test, label='Test ROC AUC {0}'.format(roc_auc_test))
    plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6))
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.show() 
    pass

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df_knn_filled, test_size = 0.3, random_state = 42, stratify = df['y'])
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
X_train = df_train.drop(columns=['y'])
X_test = df_test.drop(columns=['y'])
y_train = df_train['y']
y_test = df_test['y'].values

# %%
X_test
# Out:
#      Age  Sex  Race  Education  BiomarkerGrouping  FamHistAD  Moca  \
# 1   76.0  1.0   4.0       14.0                1.0   0.328274  22.0
# 30  66.0  0.0   2.0       16.0                2.0   0.000000  23.0
# 23  60.0  0.0   2.0       18.0                1.0   0.000000  22.0
# 55  65.0  0.0   2.0       17.0                2.0   1.000000  26.0
# 64  54.0  0.0   2.0       18.0                2.0   1.000000  26.0
# 14  75.0  1.0   4.0       17.0                1.0   0.000000  21.0
# 63  54.0  0.0   2.0       17.0                3.0   0.000000  28.0
# 77  69.0  1.0   2.0       16.0                2.0   0.571216  25.0
# 21  56.0  1.0   2.0       12.0                1.0   0.000000  20.0
# 76  80.0  1.0   2.0       17.0                1.0   1.000000  24.0
# 50  69.0  0.0   2.0       17.0                2.0   0.000000  27.0
# 2   71.0  1.0   2.0       16.0                2.0   1.000000  28.0
# 65  74.0  1.0   2.0       16.0                1.0   0.000000  24.0
# ...

# %%
X_train
# Out:
#      Age  Sex  Race  Education  BiomarkerGrouping  FamHistAD  Moca  \
# 69  58.0  1.0   2.0       14.0                2.0   1.000000  26.0
# 39  62.0  0.0   2.0       18.0                3.0   0.000000  28.0
# 52  78.0  0.0   2.0       23.0                1.0   0.000000  25.0
# 95  76.0  1.0   2.0       14.0                1.0   0.000000  24.0
# 29  64.0  0.0   4.0       12.0                1.0   0.000000  24.0
# ..   ...  ...   ...        ...                ...        ...   ...
# 44  57.0  0.0   6.0       13.0                3.0   0.000000  28.0
# 5   57.0  1.0   2.0       16.0                2.0   0.000000  27.0
# 54  62.0  0.0   2.0       14.0                1.0   0.437991  20.0
# 49  65.0  0.0   2.0       16.0                1.0   1.000000  21.0
# 70  62.0  0.0   4.0       14.0                2.0   0.000000  20.0
#
#           Ab42         Tau       ptau  ...  SLITRK4|Q8IW52  PCSK2|P16519  \
# 69  143.000000   82.000000  12.000000  ...        0.666032      0.394673
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7, weights='distance')
knn.fit(X_train_norm, y_train)

y_knn_predict = knn.predict(X_test_norm)
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_knn_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96        27
#          1.0       0.00      0.00      0.00         2
#
#     accuracy                           0.93        29
#    macro avg       0.47      0.50      0.48        29
# weighted avg       0.87      0.93      0.90        29
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(roc_auc_score(y_test, y_knn_predict))
# Out:
# 0.5

# %%
roc_auc_pic(y_knn_predict, y_test)

# %%
from sklearn.model_selection import GridSearchCV

knn_2 = KNeighborsClassifier()
params = {'n_neighbors': range(1, 17), 'weights': ['uniform', 'distance']}
grid_knn = GridSearchCV(knn_2, params, scoring="roc_auc", cv=7)
grid_knn.fit(X_train_norm, y_train)
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=7.
#   warnings.warn(
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
grid_knn.best_params_
# Out:
# {'n_neighbors': 1, 'weights': 'uniform'}

# %%
grid_knn.best_score_
# Out:
# nan

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier()
tree.fit(X_train_norm, y_train)
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# DecisionTreeClassifier()

# %%
y_tree_predict = tree.predict(X_test_norm)
print(roc_auc_score(y_test, y_tree_predict))
# Out:
# 0.6944444444444444

# %%
roc_auc_pic(y_tree_predict, y_test)

# %%
print(classification_report(y_test, y_tree_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.89      0.92        27
#          1.0       0.25      0.50      0.33         2
#
#     accuracy                           0.86        29
#    macro avg       0.60      0.69      0.63        29
# weighted avg       0.91      0.86      0.88        29

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 8)
classifier.fit(X_train, y_train)
# Out:
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
# rfc - random forest classifier 
rfc_pred = classifier.predict(X_test)
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96        27
#          1.0       0.00      0.00      0.00         2
#
#     accuracy                           0.93        29
#    macro avg       0.47      0.50      0.48        29
# weighted avg       0.87      0.93      0.90        29
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/macbook/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
print(roc_auc_score(y_test, rfc_pred))
# Out:
# 0.5

# %%
roc_auc_pic(rfc_pred, y_test)
